# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Best Cities for Startups.csv.xls")
data
# Out:
#      position change in position from 2020               city  \
# 0           1                            0  San Francisco Bay
# 1           2                            0           New York
# 2           3                            3            Beijing
# 3           4                            1   Los Angeles Area
# 4           5                            2             London
# ..        ...                          ...                ...
# 995       996                           26        Ouagadougou
# 996       997                          new            Baghdad
# 997       998                           13            Mbabane
# 998       999                          new            Conakry
# 999      1000                          new              Sanaa
#
#              country  total score  quatity score  quality score  \
# 0      United States      328.966          29.14         296.02
# 1      United States      110.777          11.43          95.55
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#      position change in position from 2020               city  \
# 0           1                            0  San Francisco Bay
# 1           2                            0           New York
# 2           3                            3            Beijing
# 3           4                            1   Los Angeles Area
# 4           5                            2             London
# ..        ...                          ...                ...
# 995       996                           26        Ouagadougou
# 996       997                          new            Baghdad
# 997       998                           13            Mbabane
# 998       999                          new            Conakry
# 999      1000                          new              Sanaa
#
#              country  total score  quatity score  quality score  \
# 0      United States      328.966          29.14         296.02
# 1      United States      110.777          11.43          95.55
# ...

# %%
df2 = df.head(50)
df2
# Out:
#     position change in position from 2020                city  \
# 0          1                            0   San Francisco Bay
# 1          2                            0            New York
# 2          3                            3             Beijing
# 3          4                            1    Los Angeles Area
# 4          5                            2              London
# 5          6                            2         Boston Area
# 6          7                            3            Shanghai
# 7          8                            1       Tel Aviv Area
# 8          9                            0              Moscow
# 9         10                            4           Bangalore
# 10        11                            1               Paris
# 11        12                            1             Seattle
# 12        13                            5              Berlin
# 13        14                            1           New Delhi
# ...

# %%
df.shape
# Out:
# (1000, 9)

# %%
plt.scatter(df2["quality score"], df2["country"])
plt.xlabel('quality score')
plt.ylabel('country')
plt.grid()
plt.savefig("country quality score.jpg", bbox_inches='tight',pad_inches= 1)
plt.show()

# %%
plt.scatter( df2["business score"], df2["country"])
plt.xlabel('business score')
plt.ylabel('country')
plt.grid()
plt.savefig("country business score.jpg", bbox_inches='tight',pad_inches= 1)
plt.show()

# %%
plt.scatter(df2["total score"], df2["country"])
plt.xlabel('total score')
plt.ylabel('country')
plt.grid()
plt.savefig("country total score.jpg", bbox_inches='tight',pad_inches= 1)
plt.show()
